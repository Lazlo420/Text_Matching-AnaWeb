# %%
from urllib.parse import urlunparse
from bs4 import BeautifulSoup
import datetime as dt
from selenium import webdriver
from time import sleep
from tqdm import tqdm

registro = {}
base_url = 'https://peru21.pe/archivo/todas/'
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)
revisar=[]

# %%
base_url = 'https://peru21.pe/archivo/todas/'
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)
for i in tqdm(range(648,731)):
    start = 736330+i
    date = dt.date.fromordinal(start)
    compilao = []
    complete_url = base_url + str(date) + '/'
    driver.get(complete_url)
    sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(5)
    updated_html = driver.page_source
    updated_soup = BeautifulSoup(updated_html, 'html.parser')
    link_elements = updated_soup.find_all('a', class_='story-item__title')
    if link_elements:
        for tag in link_elements:
            link = tag.attrs['href']
            if not link.startswith('https://peru21.pe'):
                link = urlunparse(('https', 'peru21.pe', link, '', '', ''))
            compilao.append(link)

    if len(compilao)==0:
        revisar.append(date)
    registro[date] = compilao
driver.quit()
# Out:
# 100%|██████████| 83/83 [17:13<00:00, 12.45s/it]

# %%
len(revisar)
revisar2=[]

# %%
base_url = 'https://peru21.pe/archivo/todas/'
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)
for link in revisar:
    date = link
    compilao = []
    complete_url = base_url + str(date) + '/'
    driver.get(complete_url)
    sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(10)
    updated_html = driver.page_source
    updated_soup = BeautifulSoup(updated_html, 'html.parser')
    link_elements = updated_soup.find_all('a', class_='story-item__title')
    if link_elements:
        for tag in link_elements:
            link = tag.attrs['href']
            if not link.startswith('https://peru21.pe'):
                link = urlunparse(('https', 'peru21.pe', link, '', '', ''))
            compilao.append(link)

    print(len(compilao))
    if len(compilao)==0:
        revisar2.append(date)
    registro[date] = compilao
# Out:
# 0
# 122
# 108
# 139
# 145
# 135
# 125
# 136
# 131
# 139
# 141
# 141
# 120
# 122
# 146
# 144
# 143
# 124
# 146
# 141
# 144
# 127
# 131
# 150
# 130
# 116
# 144
# 131
# 0
# 135
# 148
# 137
# 130
# 151
# 134
# 126
# 133
# 135
# 125
# 136
# 141
# 140
# 150
# 141
# 139
# 127
# 151
# 139
# 119
# 127
# 127
# 149
# 138
# 118
# 119
# 127
# 142
# 128
# 114
# 139
# 117
# 132
# 120
# 105
# 101
# 102
# 123
# 115
# 85
# 111
# 151
# 144
# 109
# 107
# 142
# 145
# 142
# 157
# 154
# 126
# 128
# 144
# 197
# 169
# 129
# 0
# 147
# 159
# 156
# 204
# 170
# 156
# 154
# 155
# 181
# 167
# 151
# 149
# 147
# 191
# 150
# 160
# 176
# 187
# 161
# 137
# 134
# 133
# 158
# 0
# 187
# 177
# 0
# 167
# 135
# 187
# 195
# 218
# 166
# 184
# 170
# 170
# 198
# 238
# 207
# 0
# 199
# 172
# 171
# 195
# 0
# 222
# 210
# 0
# 161
# 178
# 0
# 222
# 200
# 0
# 0
# 149
# 0
# 0
# 0
# 0
# 193
# 206
# 134
# 0
# 191
# 0
# 0
# 0
# 198
# 128
# 173
# 188
# 232
# 199
# 186
# 0
# 145
# 0
# 165
# 196
# 191
# 0
# 171
# 0
# 138
# 0
# 175
# 167
# 176
# 149
# 145
# 190
# 0
# 0
# 167
# 0
# 165
# 127
# 157
# 193
# 0
# 172
# 165
# 122
# 136
# 157
# 0
# 0
# 194
# 0
# 168
# 130
# 177
# 0
# 197
# 179
# 144
# 152
# 163
# 0
# 185
# 169
# 0
# 184
# 134
# 134
# 166
# 0
# 0
# 0
# 0
# 138
# 158
# 169
# 0
# 0
# 229
# 192
# 149
# 158
# 0
# 0
# 0
# 0
# 217
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25
# 25

# %%
for i in revisar[-23:]:
    revisar2.append(i)

# %%
base_url = 'https://peru21.pe/archivo/todas/'
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=options)
revisar4=[]
for link in revisar3:
    date = link
    compilao = []
    complete_url = base_url + str(date) + '/'
    driver.get(complete_url)
    sleep(5)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    sleep(10)
    updated_html = driver.page_source
    updated_soup = BeautifulSoup(updated_html, 'html.parser')
    link_elements = updated_soup.find_all('a', class_='story-item__title')
    if link_elements:
        for tag in link_elements:
            link = tag.attrs['href']
            if not link.startswith('https://peru21.pe'):
                link = urlunparse(('https', 'peru21.pe', link, '', '', ''))
            compilao.append(link)

    print(len(compilao))
    if len(compilao)==0:
        revisar4.append(date)
    registro[date] = compilao
# Out:
# 0
# 0
# 0
# 227
# 0
# 244
# 203
# 0
# 221
# 0
# 223

# %%
len(revisar3)
# Out:
# 11

# %%
with open("links_peru21.txt", "w") as file:
    for i in registro.keys():
        if registro[i]!=[]:
            for j in registro[i]:
                file.write(f'{j}\n')
